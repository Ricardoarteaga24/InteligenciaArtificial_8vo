# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardoarteaga24/InteligenciaArtificial_8vo/blob/main/Practica__parcial_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies= pd.read_csv("/content/movies.csv")
ratings= pd.read_csv("/content/ratings.csv")
tags= pd.read_csv("/content/tags.csv")

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings.index)
# Out:
# RangeIndex(start=0, stop=100836, step=1)

# %%
print(tags.index)
# Out:
# RangeIndex(start=0, stop=3683, step=1)

# %%
print(movies.index)
# Out:
# RangeIndex(start=0, stop=9742, step=1)

# %%
print(ratings.index)
print(tags.index)
print(movies.index)
# Out:
# RangeIndex(start=0, stop=100836, step=1)
# RangeIndex(start=0, stop=3683, step=1)
# RangeIndex(start=0, stop=9742, step=1)

# %%
print(ratings.columns)
print(tags.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings['rating'].describe())
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
print(ratings['rating'].min())
print(ratings['rating'].max())
print(ratings['rating'].std())
print(ratings['rating'].mode())
# Out:
# 0.5
# 5.0
# 1.0425292390605359
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
tags.shape
# Out:
# (3683, 3)

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# **identificaciones de variables vacias**

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
# %matplotlib inline
ratings.hist(column='rating', figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)
