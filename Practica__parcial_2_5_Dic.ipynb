# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardoarteaga24/InteligenciaArtificial_8vo/blob/main/Practica__parcial_2_5_Dic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
movies= pd.read_csv("/content/movies.csv")
ratings= pd.read_csv("/content/ratings.csv")
tags= pd.read_csv("/content/tags.csv")

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings.index)
# Out:
# RangeIndex(start=0, stop=100836, step=1)

# %%
print(tags.index)
# Out:
# RangeIndex(start=0, stop=3683, step=1)

# %%
print(movies.index)
# Out:
# RangeIndex(start=0, stop=9742, step=1)

# %%
print(ratings.index)
print(tags.index)
print(movies.index)
# Out:
# RangeIndex(start=0, stop=100836, step=1)
# RangeIndex(start=0, stop=3683, step=1)
# RangeIndex(start=0, stop=9742, step=1)

# %%
print(ratings.columns)
print(tags.columns)
print(movies.columns)
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0

# %%
print(ratings['rating'].describe())
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
print(ratings['rating'].min())
print(ratings['rating'].max())
print(ratings['rating'].std())
print(ratings['rating'].mode())
# Out:
# 0.5
# 5.0
# 1.0425292390605359
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
tags.shape
# Out:
# (3683, 3)

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# **identificaciones de variables vacias**

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
# %matplotlib inline
ratings.hist(column='rating', figsize=(10,4))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %% [markdown]
# **Continuacion de clase- Jueves 5 Dic 2024**

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
tags.head(10)
# Out:
#    userId  movieId                tag
# 0       2    60756              funny
# 1       2    60756    Highly quotable
# 2       2    60756       will ferrell
# 3       2    89774       Boxing story
# 4       2    89774                MMA
# 5       2    89774          Tom Hardy
# 6       2   106782              drugs
# 7       2   106782  Leonardo DiCaprio
# 8       2   106782    Martin Scorsese
# 9       7    48516       way too long

# %%
etiquetas_unicas= tags['tag'].unique()
print=(etiquetas_unicas)

# %%
type(etiquetas_unicas)
# Out:
# numpy.ndarray

# %%
print=(len(etiquetas_unicas))

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
contador_etiquetas=tags['tag'].value_counts()

# %%
type(contador_etiquetas)
# Out:
# pandas.core.series.Series

# %%
contador_etiquetas[:10].plot(kind='bar', figsize=(7,5))
# Out:
# <Axes: xlabel='tag'>

# %%
tags.head(2)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
vrb=ratings['rating']>4.5
print=(type(vrb))
print(vrb.shape)


print(vrb.head(10))
ratings[vrb].shape
# Out:
# (13211, 3)

# %%
# Out:
# 0    False
# 1    False
# 2    False
# Name: rating, dtype: bool

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
# prompt: filtro para ver cuales son las peliculas tengas la clasificacion animacion como palabra clave y cuantas son

# Filter movies with 'Animation' in the genres
animation_movies = movies[movies['genres'].str.contains('Animation', na=False)]

# Count the number of animation movies
animation_movie_count = len(animation_movies)

print(f"Number of animation movies: {animation_movie_count}")

# Display the animation movies
animation_movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 12         13                                       Balto (1995)
# 44         48                                  Pocahontas (1995)
# 205       239                              Goofy Movie, A (1995)
# 272       313                          Swan Princess, The (1994)
# ...       ...                                                ...
# 9733   193567  anohana: The Flower We Saw That Day - The Movi...
# 9735   193573            Love Live! The School Idol Movie (2015)
# 9737   193581          Black Butler: Book of the Atlantic (2017)
# 9738   193583                       No Game No Life: Zero (2017)
# 9740   193587                Bungo Stray Dogs: Dead Apple (2018)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 12                   Adventure|Animation|Children
# ...

# %%
filtro=movies['genres'].str.contains('Animation')
print(filtro.shape)
# Out:
# 0    9742
# dtype: int64

# %%
movies[filtro].shape
# Out:
# (611, 3)
